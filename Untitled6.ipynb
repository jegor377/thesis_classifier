# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use("ggplot")

# %%
df = pd.read_csv('base model analysis/train_acc-val_acc.csv')

# %%
df.head()
# Out:
#                   Run                            Run ID     metric  step  \
# 0  indecisive-hen-781  c9aa4032807b461f8fbc8aafe3b28f1a  train_acc     0
# 1  indecisive-hen-781  c9aa4032807b461f8fbc8aafe3b28f1a  train_acc     1
# 2  indecisive-hen-781  c9aa4032807b461f8fbc8aafe3b28f1a  train_acc     2
# 3  indecisive-hen-781  c9aa4032807b461f8fbc8aafe3b28f1a  train_acc     3
# 4  indecisive-hen-781  c9aa4032807b461f8fbc8aafe3b28f1a  train_acc     4
#
#        timestamp     value
# 0  1753051118926  0.207323
# 1  1753051327471  0.221735
# 2  1753051536527  0.219982
# 3  1753051744040  0.231084
# 4  1753051953091  0.239556

# %%
df2 = {}
for i, el in df.iterrows():
    if el['step'] not in df2:
        df2[el['step']] = {}
    df2[el['step']][el['metric']] = el['value']

# %%
df3 = {
    'step': [],
    'Zbiór treningowy': [],
    'Zbiór walidacyjny': []
}
for i, x in df2.items():
    df3['step'].append(i)
    df3['Zbiór treningowy'].append(df2[i]['train_acc'])
    df3['Zbiór walidacyjny'].append(df2[i]['val_acc'])
df3 = pd.DataFrame.from_dict(df3)

# %%
df3
# Out:
#     step  Zbiór treningowy  Zbiór walidacyjny
# 0      0          0.207323           0.242991
# 1      1          0.221735           0.192368
# 2      2          0.219982           0.195483
# 3      3          0.231084           0.213396
# 4      4          0.239556           0.258567
# 5      5          0.236732           0.257009
# 6      6          0.251534           0.257009
# 7      7          0.253676           0.232087
# 8      8          0.252800           0.231308
# 9      9          0.253773           0.261682
# 10    10          0.256695           0.264798
# 11    11          0.258935           0.254673
# 12    12          0.256305           0.258567
# 13    13          0.251534           0.255452
# 14    14          0.259811           0.252336
# 15    15          0.258156           0.245327
# 16    16          0.262440           0.254673
# 17    17          0.262343           0.255452
# 18    18          0.268965           0.250779
# 19    19          0.262635           0.260903
# 20    20          0.262538           0.267913
# 21    21          0.263804           0.263240
# 22    22          0.268673           0.239097
# 23    23          0.270426           0.252336
# 24    24          0.262732           0.264798
# 25    25          0.267504           0.249221
# 26    26          0.262830           0.263240
# 27    27          0.271107           0.266355
# 28    28          0.262148           0.263240
# 29    29          0.269257           0.273364

# %%
ax = df3.plot(x='step', y=['Zbiór treningowy', 'Zbiór walidacyjny'])
ax.set_title('Porównanie dokładności na zbiorze\ntreningowym i walidacyjnym podczas trenowania')
ax.set_xlabel('Epoka')
ax.set_ylabel('Dokładność')

plt.savefig('base model analysis/base_model_train_vs_val_acc.png')
plt.show()

# %%
df = pd.read_csv('base model analysis/train_loss-val_loss.csv')

# %%
df2 = {}
for i, el in df.iterrows():
    if el['step'] not in df2:
        df2[el['step']] = {}
    df2[el['step']][el['metric']] = el['value']

# %%
df3 = {
    'step': [],
    'Zbiór treningowy': [],
    'Zbiór walidacyjny': []
}
for i, x in df2.items():
    df3['step'].append(i)
    df3['Zbiór treningowy'].append(df2[i]['train_loss'])
    df3['Zbiór walidacyjny'].append(df2[i]['val_loss'])
df3 = pd.DataFrame.from_dict(df3)

# %%
ax = df3.plot(x='step', y=['Zbiór treningowy', 'Zbiór walidacyjny'])
ax.set_title('Porównanie wartości funkcji straty na zbiorze\ntreningowym i walidacyjnym podczas trenowania')
ax.set_xlabel('Epoka')
ax.set_ylabel('Wartość funkcji straty')

plt.savefig('base model analysis/base_model_train_vs_val_loss.png')
plt.show()
