# %%
import pandas as pd
import numpy as np
import ast

# %%
pd.set_option('display.max_columns', None)

# %%
sm_correct_sma_incorrect = pd.read_csv('analysis/SM_correct_SMA_incorrect_csv.csv')

# %%
#sm_correct_sma_incorrect['SM_prob_np'] = sm_correct_sma_incorrect['SM_prob'].apply(lambda x: np.array(ast.literal_eval(x)))
#sm_correct_sma_incorrect['SMA_prob_np'] = sm_correct_sma_incorrect['SMA_prob'].apply(lambda x: np.array(ast.literal_eval(x)))

# %%
#sm_correct_sma_incorrect['SM_prob_entropy'] = sm_correct_sma_incorrect['SM_prob_np'].apply(lambda x: -(x*np.log2(x)).sum())
#sm_correct_sma_incorrect['SMA_prob_entropy'] = sm_correct_sma_incorrect['SMA_prob_np'].apply(lambda x: -(x*np.log2(x)).sum())

# %%
sm_correct_sma_incorrect.describe()
# Out:
#               id  label_num  SM_highest_prob  SMA_highest_prob  prob_diff  \
# count  30.000000  30.000000        30.000000         30.000000  30.000000
# mean   15.500000   4.866667         0.340307          0.345760  -0.005452
# std     8.803408   0.345746         0.034887          0.032409   0.058656
# min     1.000000   4.000000         0.281696          0.285899  -0.107114
# 25%     8.250000   5.000000         0.320189          0.321917  -0.057714
# 50%    15.500000   5.000000         0.333394          0.340001  -0.002047
# 75%    22.750000   5.000000         0.353589          0.371602   0.028325
# max    30.000000   5.000000         0.428659          0.403790   0.142760
#
#        SM_prob_entropy  SMA_prob_entropy    SM_pred   SMA_pred  \
# count        30.000000         30.000000  30.000000  30.000000
# mean          2.213776          2.171723   4.866667   3.366667
# std           0.104166          0.136584   0.345746   0.999425
# min           1.928111          1.948270   4.000000   1.000000
# 25%           2.183481          2.040045   5.000000   3.000000
# 50%           2.241699          2.196853   5.000000   4.000000
# 75%           2.295961          2.250446   5.000000   4.000000
# max           2.378940          2.470298   5.000000   5.000000
#
#        Rok informacji  justification_correct  Tematyczność  Generyczność  \
# count       30.000000              30.000000     30.000000     30.000000
# mean      2012.333333               0.433333      0.966667      0.566667
# std          2.353769               0.504007      0.182574      0.504007
# min       2008.000000               0.000000      0.000000      0.000000
# 25%       2011.000000               0.000000      1.000000      0.000000
# 50%       2012.000000               0.000000      1.000000      1.000000
# 75%       2014.000000               1.000000      1.000000      1.000000
# max       2016.000000               1.000000      1.000000      1.000000
#
#        Konkretność  Redundancja  Dodaje info  Informacyjność  \
# count    30.000000    30.000000    30.000000       30.000000
# mean      0.400000     0.333333     0.633333        0.633333
# std       0.498273     0.479463     0.490133        0.490133
# min       0.000000     0.000000     0.000000        0.000000
# 25%       0.000000     0.000000     0.000000        0.000000
# 50%       0.000000     0.000000     1.000000        1.000000
# 75%       1.000000     1.000000     1.000000        1.000000
# max       1.000000     1.000000     1.000000        1.000000
#
#        Prawdziwość 1 (prawda)  Prawdziwość 1 (częściowa)  \
# count               30.000000                  30.000000
# mean                 0.133333                   0.566667
# std                  0.345746                   0.504007
# min                  0.000000                   0.000000
# 25%                  0.000000                   0.000000
# 50%                  0.000000                   1.000000
# 75%                  0.000000                   1.000000
# max                  1.000000                   1.000000
#
#        Prawdziwość 1 (fałsz)  Prawdziwość 1 (nieznana)  \
# count              30.000000                 30.000000
# mean                0.133333                  0.133333
# std                 0.345746                  0.345746
# min                 0.000000                  0.000000
# 25%                 0.000000                  0.000000
# 50%                 0.000000                  0.000000
# 75%                 0.000000                  0.000000
# max                 1.000000                  1.000000
#
#        Prawdziwość 2 (prawda)  Prawdziwość 2 (częściowa)  \
# count               30.000000                  30.000000
# mean                 0.066667                   0.433333
# std                  0.253708                   0.504007
# min                  0.000000                   0.000000
# 25%                  0.000000                   0.000000
# 50%                  0.000000                   0.000000
# 75%                  0.000000                   1.000000
# max                  1.000000                   1.000000
#
#        Prawdziwość 2 (fałsz)  Użyteczność  Szkodliwość   Zgodność  \
# count              30.000000    30.000000    30.000000  30.000000
# mean                0.166667     0.300000     0.166667   0.966667
# std                 0.379049     0.466092     0.379049   0.182574
# min                 0.000000     0.000000     0.000000   0.000000
# 25%                 0.000000     0.000000     0.000000   1.000000
# 50%                 0.000000     0.000000     0.000000   1.000000
# 75%                 0.000000     1.000000     0.000000   1.000000
# max                 1.000000     1.000000     1.000000   1.000000
#
#        Neutralność  Odwrotność  barely_true_counts  false_counts  \
# count         30.0        30.0           30.000000     30.000000
# mean           0.0         0.0           11.866667     10.800000
# std            0.0         0.0           23.036303     22.173921
# min            0.0         0.0            0.000000      0.000000
# 25%            0.0         0.0            0.000000      0.000000
# 50%            0.0         0.0            1.000000      0.000000
# 75%            0.0         0.0            3.500000      4.500000
# max            0.0         0.0           70.000000     71.000000
#
#        half_true_counts  mostly_true_counts  pants_on_fire_counts  \
# count         30.000000           30.000000             30.000000
# mean          24.800000           26.033333              1.966667
# std           50.171705           51.578185              3.200036
# min            0.000000            0.000000              0.000000
# 25%            1.000000            0.000000              0.000000
# 50%            2.000000            3.000000              0.000000
# 75%            9.500000           10.000000              2.500000
# max          160.000000          163.000000              9.000000
#
#        grammar_errors  ratio_of_capital_letters   sort_key
# count       30.000000                 30.000000  30.000000
# mean         0.366667                  2.565333   0.117098
# std          0.614948                  1.793665   0.011493
# min          0.000000                  0.580000   0.104683
# 25%          0.000000                  1.360000   0.108576
# 50%          0.000000                  2.435000   0.114696
# 75%          1.000000                  3.282500   0.120646
# max          2.000000                  8.840000   0.157303

# %%
sm_incorrect_sma_correct = pd.read_csv('analysis/SM_incorrect_SMA_correct_csv.csv')

# %%
#sm_incorrect_sma_correct['SM_prob_np'] = sm_incorrect_sma_correct['SM_prob'].apply(lambda x: np.array(ast.literal_eval(x)))
#sm_incorrect_sma_correct['SMA_prob_np'] = sm_incorrect_sma_correct['SMA_prob'].apply(lambda x: np.array(ast.literal_eval(x)))

# %%
#sm_incorrect_sma_correct['SM_prob_entropy'] = sm_incorrect_sma_correct['SM_prob_np'].apply(lambda x: -(x*np.log2(x)).sum())
#sm_incorrect_sma_correct['SMA_prob_entropy'] = sm_incorrect_sma_correct['SMA_prob_np'].apply(lambda x: -(x*np.log2(x)).sum())

# %%
sm_incorrect_sma_correct.describe()
# Out:
#               id  label_num  SM_highest_prob  SMA_highest_prob  prob_diff  \
# count  30.000000  30.000000        30.000000         30.000000  30.000000
# mean   15.500000   2.233333         0.342479          0.389450   0.046971
# std     8.803408   1.695498         0.044550          0.067172   0.104799
# min     1.000000   0.000000         0.267069          0.267328  -0.178361
# 25%     8.250000   1.000000         0.312648          0.342631  -0.027494
# 50%    15.500000   2.000000         0.335887          0.374735   0.039411
# 75%    22.750000   4.000000         0.367603          0.419650   0.119898
# max    30.000000   5.000000         0.445690          0.539236   0.228541
#
#        SM_prob_entropy  SMA_prob_entropy    SM_pred   SMA_pred  \
# count        30.000000         30.000000  30.000000  30.000000
# mean          2.249405          2.144184   4.566667   2.233333
# std           0.116994          0.200662   0.817200   1.695498
# min           2.044183          1.802033   3.000000   0.000000
# 25%           2.177798          2.006961   5.000000   1.000000
# 50%           2.262456          2.158436   5.000000   2.000000
# 75%           2.318379          2.302486   5.000000   4.000000
# max           2.515285          2.464178   5.000000   5.000000
#
#        Rok informacji  justification_correct  Tematyczność  Generyczność  \
# count       30.000000              30.000000          30.0     30.000000
# mean      2012.400000               0.400000           1.0      0.533333
# std          2.268221               0.498273           0.0      0.507416
# min       2008.000000               0.000000           1.0      0.000000
# 25%       2011.000000               0.000000           1.0      0.000000
# 50%       2012.000000               0.000000           1.0      1.000000
# 75%       2014.000000               1.000000           1.0      1.000000
# max       2016.000000               1.000000           1.0      1.000000
#
#        Konkretność  Redundancja  Dodaje info  Informacyjność  \
# count    30.000000    30.000000    30.000000       30.000000
# mean      0.466667     0.333333     0.666667        0.766667
# std       0.507416     0.479463     0.479463        0.430183
# min       0.000000     0.000000     0.000000        0.000000
# 25%       0.000000     0.000000     0.000000        1.000000
# 50%       0.000000     0.000000     1.000000        1.000000
# 75%       1.000000     1.000000     1.000000        1.000000
# max       1.000000     1.000000     1.000000        1.000000
#
#        Prawdziwość 1 (prawda)  Prawdziwość 1 (częściowa)  \
# count               30.000000                  30.000000
# mean                 0.266667                   0.533333
# std                  0.449776                   0.507416
# min                  0.000000                   0.000000
# 25%                  0.000000                   0.000000
# 50%                  0.000000                   1.000000
# 75%                  0.750000                   1.000000
# max                  1.000000                   1.000000
#
#        Prawdziwość 1 (fałsz)  Prawdziwość 1 (nieznana)  \
# count              30.000000                 30.000000
# mean                0.166667                  0.033333
# std                 0.379049                  0.182574
# min                 0.000000                  0.000000
# 25%                 0.000000                  0.000000
# 50%                 0.000000                  0.000000
# 75%                 0.000000                  0.000000
# max                 1.000000                  1.000000
#
#        Prawdziwość 2 (prawda)  Prawdziwość 2 (częściowa)  \
# count               30.000000                  30.000000
# mean                 0.300000                   0.300000
# std                  0.466092                   0.466092
# min                  0.000000                   0.000000
# 25%                  0.000000                   0.000000
# 50%                  0.000000                   0.000000
# 75%                  1.000000                   1.000000
# max                  1.000000                   1.000000
#
#        Prawdziwość 2 (fałsz)  Użyteczność  Szkodliwość   Zgodność  \
# count              30.000000    30.000000    30.000000  30.000000
# mean                0.166667     0.733333     0.100000   0.800000
# std                 0.379049     0.449776     0.305129   0.406838
# min                 0.000000     0.000000     0.000000   0.000000
# 25%                 0.000000     0.250000     0.000000   1.000000
# 50%                 0.000000     1.000000     0.000000   1.000000
# 75%                 0.000000     1.000000     0.000000   1.000000
# max                 1.000000     1.000000     1.000000   1.000000
#
#        Neutralność  Odwrotność  barely_true_counts  false_counts  \
# count    30.000000   30.000000           30.000000     30.000000
# mean      0.066667    0.133333           11.266667     11.000000
# std       0.253708    0.345746           21.588524     21.677893
# min       0.000000    0.000000            0.000000      0.000000
# 25%       0.000000    0.000000            0.000000      1.000000
# 50%       0.000000    0.000000            1.000000      1.500000
# 75%       0.000000    0.000000            9.000000      5.750000
# max       1.000000    1.000000           70.000000     71.000000
#
#        half_true_counts  mostly_true_counts  pants_on_fire_counts  \
# count         30.000000           30.000000             30.000000
# mean          21.666667           21.800000              2.566667
# std           48.193098           48.883676              4.966671
# min            0.000000            0.000000              0.000000
# 25%            0.000000            0.000000              0.000000
# 50%            1.500000            1.000000              1.000000
# 75%           10.750000           16.250000              1.000000
# max          160.000000          163.000000             18.000000
#
#        grammar_errors  ratio_of_capital_letters   sort_key
# count       30.000000                 30.000000  30.000000
# mean         0.266667                  3.296667   0.131211
# std          0.639684                  2.083625   0.014570
# min          0.000000                  0.620000   0.116187
# 25%          0.000000                  1.735000   0.120267
# 50%          0.000000                  2.885000   0.126054
# 75%          0.000000                  4.262500   0.138831
# max          3.000000                  9.300000   0.169454

# %%
sm_correct_sma_incorrect['Rok informacji'].value_counts().sort_index().plot(kind='barh')
# Out:
# <Axes: ylabel='Rok informacji'>

# %%
sm_incorrect_sma_correct['Rok informacji'].value_counts().sort_index().plot(kind='barh')
# Out:
# <Axes: ylabel='Rok informacji'>

# %%
sm_correct_sma_incorrect['Użyteczność'].value_counts().sort_index().plot(kind='barh')
# Out:
# <Axes: ylabel='Użyteczność'>

# %%
sm_incorrect_sma_correct['Użyteczność'].value_counts().sort_index().plot(kind='barh')
# Out:
# <Axes: ylabel='Użyteczność'>
