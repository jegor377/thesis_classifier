# %%
import pandas as pd

# %%
df1 = pd.read_csv('analysis/results/SM_correct_SMA_incorrect_SM_dominance_analysed.csv')

# %%
df1
# Out:
#    SM_pred  SMA_pred  label_num  SM_highest_prob  SMA_highest_prob  \
# 0        5         3          5         0.431197          0.239996
# 1        5         3          5         0.428659          0.285899
# 2        4         3          4         0.418661          0.375729
# 3        5         2          5         0.399270          0.302438
# 4        5         3          5         0.393781          0.231457
# 5        5         3          5         0.389911          0.256266
# 6        5         1          5         0.386184          0.311560
# 7        5         1          5         0.384465          0.224094
# 8        5         3          5         0.381500          0.309929
# 9        5         3          5         0.374749          0.259642
#
#                                            statement  \
# 0  In the 2000 Florida election, at least 1,100 e...
# 1  Says Milken Institute rated San Antonio as nat...
# 2  As weve seen that federal support for states d...
# ...

# %%
df1.describe()
# Out:
#          SM_pred   SMA_pred  label_num  SM_highest_prob  SMA_highest_prob  \
# count  10.000000  10.000000  10.000000        10.000000         10.000000
# mean    4.900000   2.500000   4.900000         0.398838          0.279701
# std     0.316228   0.849837   0.316228         0.020228          0.046730
# min     4.000000   1.000000   4.000000         0.374749          0.224094
# 25%     5.000000   2.250000   5.000000         0.384895          0.244064
# 50%     5.000000   3.000000   5.000000         0.391846          0.272770
# 75%     5.000000   3.000000   5.000000         0.413813          0.308056
# max     5.000000   3.000000   5.000000         0.431197          0.375729
#
#        Tematyczność  Generyczność  Redundancja  Informacyjność  Prawdziwość  \
# count     10.000000      9.000000     9.000000        9.000000     9.000000
# mean       0.900000      0.555556     0.111111        0.777778     1.333333
# ...
