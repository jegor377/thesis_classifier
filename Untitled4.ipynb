# %%
import torch

# %%
torch.softmax(torch.tensor([1,2,3], dtype=torch.float32), dim=0)
# Out:
# tensor([0.0900, 0.2447, 0.6652])

# %%
torch.log_softmax(torch.tensor([1,2,3], dtype=torch.float32), dim=0)
# Out:
# tensor([-2.4076, -1.4076, -0.4076])

# %%
import pandas as pd

# %%
df = pd.read_csv('data/normalized/val2.csv')

# %%
df.shape
# Out:
# (1284, 25)

# %%
df['label'].value_counts()
# Out:
# label
# false          263
# mostly-true    251
# half-true      248
# barely-true    237
# true           169
# pants-fire     116
# Name: count, dtype: int64
